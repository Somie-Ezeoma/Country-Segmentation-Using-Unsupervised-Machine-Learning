# %% [markdown]
# ### CLUSTERING ANALYSIS ON COUNTRY DATASET USING KMEAN

# %%
# Importing libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O 
import matplotlib.pyplot as plt # MATLAB-like way of plotting
from matplotlib.colors import Normalize

# %%
# sklearn package for machine learning in python:
from sklearn.cluster import KMeans

# %%
# This reads data .csv file in a folder
df = pd.read_csv(r"C:\Users\NewUser\Desktop\Assignment AI\country_data.csv")

# %%
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# 1         4.49        76.3       1.65   4090
# 2        16.10        76.5       2.89   4460
# 3        22.40        60.1       6.16   3530
# 4         1.44        76.8       2.13  12200
# ..         ...         ...        ...    ...
# 162       2.62        63.0       3.50   2970
# 163      45.90        75.4       2.47  13500
# 164      12.10        73.1       1.95   1310
# 165      23.60        67.5       4.67   1310
# 166      14.00        52.0       5.40   1460
#
# [167 rows x 10 columns]

# %%
# This duplicates the data set 'df1'
df1=df.copy()

# %%
# This prints the first 5 rows of the data
df1.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
# This removes all the null values in the dataset
df1.isnull()
# Out:
#      country  child_mort  exports  health  imports  income  inflation  \
# 0      False       False    False   False    False   False      False
# 1      False       False    False   False    False   False      False
# 2      False       False    False   False    False   False      False
# 3      False       False    False   False    False   False      False
# 4      False       False    False   False    False   False      False
# ..       ...         ...      ...     ...      ...     ...        ...
# 162    False       False    False   False    False   False      False
# 163    False       False    False   False    False   False      False
# 164    False       False    False   False    False   False      False
# 165    False       False    False   False    False   False      False
# 166    False       False    False   False    False   False      False
#
#      life_expec  total_fer   gdpp
# 0         False      False  False
# 1         False      False  False
# 2         False      False  False
# 3         False      False  False
# 4         False      False  False
# ..          ...        ...    ...
# 162       False      False  False
# 163       False      False  False
# 164       False      False  False
# 165       False      False  False
# 166       False      False  False
#
# [167 rows x 10 columns]

# %%
# This sums up all the columns to show the null values in the data set
df1.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # This sums up all the columns to show the null values in the data set
# ----> 2 df1.isnull().sum()
#
# NameError: name 'df1' is not defined

# %%
# This gives a description of Total Entries, Number of Columns, Datatype

# %%
df1.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# 50%      5.390000   73.100000    2.410000    4660.000000
# 75%     10.750000   76.800000    3.880000   14050.000000
# max    104.000000   82.800000    7.490000  105000.000000

# %%
# X = df[['child_mort']]
# y = df.[['health']]
X = df1.iloc[:, [1, 3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # X = df[['child_mort']]
#       2 # y = df.[['health']]
# ----> 3 X = df1.iloc[:, [1, 3]]
#
# NameError: name 'df1' is not defined

# %%
X

# %%
# This tells algorithm the number of clusters it should look for
KM1 = KMeans(n_clusters = 2, n_init='auto', random_state=5)

# %%
# This runs the Kmeans algorithm for the data X
KM1.fit(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # This runs the Kmeans algorithm for the data X
# ----> 2 KM1.fit(X)
#
# NameError: name 'KM1' is not defined

# %%
# This prints the centre positions of the clusters
KM1.cluster_centers_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 KM1.cluster_centers_
#
# NameError: name 'KM1' is not defined

# %%
centroids = KM1.cluster_centers_

# %%
centroids
# Out:
# array([[ 6.33537037, 59.79074074,  4.65222222],
#        [ 7.04522124, 75.7       ,  2.13353982]])

# %%
# This Visualises the result
fig, ax = plt.subplots()

# This stores the normalisation of the color encodings based on the number of clusters
nm = Normalize(vmin = 0, vmax = len(centroids)-1)

# This plots the clustered data
ax.scatter(X.iloc[:, 0], X.iloc[:, 1], c = KM1.predict(X), s = 50, cmap = 'plasma', norm = nm)

# This plots the centroids using a for loop
for i in range(centroids.shape[0]):
    ax.text(centroids[i, 0],centroids[i, 1], str(i), c = 'black',
    bbox=dict(boxstyle="round", facecolor='white', edgecolor='black'))

ax.set_xlabel('child_mort')
ax.set_ylabel('health')

# %% [markdown]
# ### 2nd Model

# %%
# X = df[['exports']]
# y = df.[['gdpp']]
X = df1.iloc[:, [2, 9]]

# %%
X
# Out:
#      exports   gdpp
# 0       10.0    553
# 1       28.0   4090
# 2       38.4   4460
# 3       62.3   3530
# 4       45.5  12200
# ..       ...    ...
# 162     46.6   2970
# 163     28.5  13500
# 164     72.0   1310
# 165     30.0   1310
# 166     37.0   1460
#
# [167 rows x 2 columns]

# %%
# This tells algorithm the number of clusters it should look for
KM3 = KMeans(n_clusters = 2, n_init='auto', random_state=5)

# %%
# This runs the Kmeans algorithm for the data X
KM3.fit(X)
# Out:
# C:\Users\NewUser\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2, n_init='auto', random_state=5)

# %%
# This prints the centre positions of the clusters
KM3.cluster_centers_
# Out:
# array([[3.81313796e+01, 5.49937226e+03],
#        [5.47066667e+01, 4.70533333e+04]])

# %%
centroids2 = KM3.cluster_centers_

# %%
centroids2
# Out:
# array([[3.81313796e+01, 5.49937226e+03],
#        [5.47066667e+01, 4.70533333e+04]])

# %%
# This Visualises the result
fig, ax = plt.subplots()

# This stores the normalisation of the color encodings based on the number of clusters
nm = Normalize(vmin = 0, vmax = len(centroids2)-1)

# This plots the clustered data
ax.scatter(X.iloc[:, 0], X.iloc[:, 1], c = KM3.predict(X), s = 50, cmap = 'plasma', norm = nm)

# This plots the centroids using a for loop
for i in range(centroids2.shape[0]):
    ax.text(centroids2[i, 0],centroids2[i, 1], str(i), c = 'black',
    bbox=dict(boxstyle="round", facecolor='white', edgecolor='black'))

ax.set_xlabel('exports')
ax.set_ylabel('gdpp')
# Out:
# Text(0, 0.5, 'gdpp')

# %% [markdown]
# ### This section plots for more than one feature

# %%
X = df.iloc[:, [3, 7, 8]]

# %%
X
# Out:
#      health  life_expec  total_fer
# 0      7.58        56.2       5.82
# 1      6.55        76.3       1.65
# 2      4.17        76.5       2.89
# 3      2.85        60.1       6.16
# 4      6.03        76.8       2.13
# ..      ...         ...        ...
# 162    5.25        63.0       3.50
# 163    4.91        75.4       2.47
# 164    6.84        73.1       1.95
# 165    5.18        67.5       4.67
# 166    5.89        52.0       5.40
#
# [167 rows x 3 columns]

# %%
# This tells algorithm the number of clusters it should look for
KM2 = KMeans(n_clusters = 5, n_init='auto', random_state=5)

# %%
KM2.fit(X)
# Out:
# C:\Users\NewUser\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=5, n_init='auto', random_state=5)

# %%
KM2.cluster_centers_
# Out:
# array([[ 7.25703704, 56.54814815,  5.26851852],
#        [ 9.56138889, 80.38611111,  1.75027778],
#        [ 6.08046154, 74.36      ,  2.20107692],
#        [ 6.91      , 32.1       ,  3.33      ],
#        [ 5.15605263, 65.7       ,  3.70131579]])

# %%
centroids1 = KM2.cluster_centers_

# %%
centroids1
# Out:
# array([[ 7.25703704, 56.54814815,  5.26851852],
#        [ 9.56138889, 80.38611111,  1.75027778],
#        [ 6.08046154, 74.36      ,  2.20107692],
#        [ 6.91      , 32.1       ,  3.33      ],
#        [ 5.15605263, 65.7       ,  3.70131579]])

# %%
# This Visualises the result in a 3D plot
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection = '3d')

# This stores the normalisation of the color encodings based on the number of clusters
nm = Normalize(vmin = 0, vmax = len(centroids1)-1)

# This plots the clustered data
scatter1 = ax.scatter(X.iloc[:, 0], X.iloc[:, 1], X.iloc[:,2],
c = KM2.predict(X), s = 50, cmap = 'plasma', norm = nm)

# This plots the centroids using a for loop
for i in range(centroids1.shape[0]):
    ax.text(centroids1[i, 0], centroids1[i, 1], centroids1[i, 2],
    str(i), c = 'black',
    bbox=dict(boxstyle="round", facecolor='white',
    edgecolor='black'))
ax.azim = -60
ax.dist = 12
ax.elev = 10

# This makes sure you choose the correct column names here!!!
ax.set_xlabel(df.columns[3])
ax.set_ylabel(df.columns[7])
ax.set_zlabel(df.columns[8])

# This produces a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter1.legend_elements(),
loc="center left", title="Clusters")
ax.add_artist(legend1)
fig.tight_layout(pad=-2.0)

fig.savefig('cluster_3Dplot.png')
# Out:
# C:\Users\NewUser\AppData\Local\Temp\ipykernel_14132\1813031892.py:20: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 12

# %% [markdown]
# ### 2nd

# %%
X = df.iloc[:, [4, 5, 6]]

# %%
X
# Out:
#      imports  income  inflation
# 0       44.9    1610       9.44
# 1       48.6    9930       4.49
# 2       31.4   12900      16.10
# 3       42.9    5900      22.40
# 4       58.9   19100       1.44
# ..       ...     ...        ...
# 162     52.7    2950       2.62
# 163     17.6   16500      45.90
# 164     80.2    4490      12.10
# 165     34.4    4480      23.60
# 166     30.9    3280      14.00
#
# [167 rows x 3 columns]

# %%
# This tells algorithm the number of clusters it should look for
KM4 = KMeans(n_clusters = 5, n_init='auto', random_state=5)

# %%
KM4.fit(X)
# Out:
# C:\Users\NewUser\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=5, n_init='auto', random_state=5)

# %%
KM4.cluster_centers_
# Out:
# array([[4.68800819e+01, 3.46990278e+03, 1.01999444e+01],
#        [4.14818182e+01, 4.38727273e+04, 3.47577273e+00],
#        [5.58434783e+01, 2.62608696e+04, 4.28008696e+00],
#        [7.96400000e+01, 8.89200000e+04, 7.69080000e+00],
#        [4.13355556e+01, 1.33228889e+04, 7.81793333e+00]])

# %%
centroids3 = KM4.cluster_centers_

# %%
centroids3
# Out:
# array([[4.68800819e+01, 3.46990278e+03, 1.01999444e+01],
#        [4.14818182e+01, 4.38727273e+04, 3.47577273e+00],
#        [5.58434783e+01, 2.62608696e+04, 4.28008696e+00],
#        [7.96400000e+01, 8.89200000e+04, 7.69080000e+00],
#        [4.13355556e+01, 1.33228889e+04, 7.81793333e+00]])

# %%
# This Visualises the result in a 3D plot
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection = '3d')

# This stores the normalisation of the color encodings based on the number of clusters
nm = Normalize(vmin = 0, vmax = len(centroids3)-1)

# This plots the clustered data
scatter2 = ax.scatter(X.iloc[:, 0], X.iloc[:, 1], X.iloc[:,2],
c = KM4.predict(X), s = 50, cmap = 'plasma', norm = nm)

# This plots the centroids using a for loop
for i in range(centroids1.shape[0]):
    ax.text(centroids3[i, 0], centroids3[i, 1], centroids3[i, 2],
    str(i), c = 'black',
    bbox=dict(boxstyle="round", facecolor='white',
    edgecolor='black'))
ax.azim = -60
ax.dist = 12
ax.elev = 10

# This makes sure you choose the correct column names here!!!
ax.set_xlabel(df.columns[4])
ax.set_ylabel(df.columns[5])
ax.set_zlabel(df.columns[6])

# This produces a legend with the unique colors from the scatter
legend2 = ax.legend(*scatter2.legend_elements(),
loc="center left", title="Clusters")
ax.add_artist(legend2)
fig.tight_layout(pad=-2.0)

fig.savefig('cluster_3Dplot.png')
# Out:
# C:\Users\NewUser\AppData\Local\Temp\ipykernel_4408\2410685115.py:19: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 12

# %%
la = KM2.labels_

# %%
la
# Out:
# array([0, 2, 2, 0, 2, 2, 2, 1, 1, 4, 2, 2, 2, 2, 2, 1, 2, 4, 2, 2, 1, 0,
#        2, 2, 2, 0, 0, 4, 0, 1, 2, 0, 0, 1, 2, 2, 4, 0, 4, 1, 0, 2, 1, 1,
#        1, 2, 2, 2, 2, 4, 4, 2, 4, 1, 1, 4, 4, 2, 1, 4, 1, 2, 2, 0, 0, 4,
#        3, 2, 1, 4, 4, 2, 4, 1, 1, 1, 2, 1, 2, 4, 4, 0, 2, 4, 4, 2, 1, 0,
#        0, 2, 2, 1, 2, 4, 0, 2, 2, 0, 1, 4, 2, 4, 2, 4, 2, 2, 0, 4, 0, 4,
#        1, 1, 0, 0, 1, 2, 4, 1, 2, 2, 4, 2, 1, 2, 2, 4, 4, 2, 2, 4, 2, 2,
#        0, 1, 2, 1, 4, 0, 1, 1, 2, 2, 4, 2, 1, 1, 4, 0, 2, 2, 0, 4, 2, 1,
#        4, 0, 2, 2, 1, 1, 2, 4, 4, 2, 2, 4, 0])

# %%
df_example=df.copy()

# %%
df_example
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# 1         4.49        76.3       1.65   4090
# 2        16.10        76.5       2.89   4460
# 3        22.40        60.1       6.16   3530
# 4         1.44        76.8       2.13  12200
# ..         ...         ...        ...    ...
# 162       2.62        63.0       3.50   2970
# 163      45.90        75.4       2.47  13500
# 164      12.10        73.1       1.95   1310
# 165      23.60        67.5       4.67   1310
# 166      14.00        52.0       5.40   1460
#
# [167 rows x 10 columns]

# %%
df_example['cluster_label'] = la

# %%
df_example
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp  birth  cluster_label
# 0         9.44        56.2       5.82    553      0              0
# 1         4.49        76.3       1.65   4090      2              2
# 2        16.10        76.5       2.89   4460      2              2
# 3        22.40        60.1       6.16   3530      0              0
# 4         1.44        76.8       2.13  12200      2              2
# ..         ...         ...        ...    ...    ...            ...
# 162       2.62        63.0       3.50   2970      4              4
# 163      45.90        75.4       2.47  13500      2              2
# 164      12.10        73.1       1.95   1310      2              2
# 165      23.60        67.5       4.67   1310      4              4
# 166      14.00        52.0       5.40   1460      0              0
#
# [167 rows x 12 columns]

# %%
print(df_example[df_example['cluster_label'] == 0])
# Out:
#                       country  child_mort  exports  health  imports  income  \
#